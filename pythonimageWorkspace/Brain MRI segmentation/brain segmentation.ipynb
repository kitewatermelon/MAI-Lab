# %% [markdown]
# ## 1. tif 파일 로드

# %%
import cv2
from PIL import Image
from IPython.display import display

img1 = Image.open('TCGA_CS_4941_19960909_1.tif', 'r')
display(img1)
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=256x256>

# %% [markdown]
# 궁금증1: 색을 다르게 표시하는 이유가 무엇일까?

# %% [markdown]
# ## 2. DCM 파일 로드
#
# 참고 자료
# https://mlhive.com/2023/02/read-and-process-dicom-files-using-python#:~:text=Installing%20PyDICOM%20Package&text=Those%20will%20be%20automatically%20installed%20with%20PyDICOM%20installation.&text=Once%20PyDICOM%20is%20installed%2C%20you,read%20its%20content%20and%20metadata.

# %%
import cv2
import matplotlib.pyplot as plt
import pydicom

ds = pydicom.dcmread('1-12.dcm')

img = ds.pixel_array
plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[12], line 7
#       3 import pydicom
#       5 ds = pydicom.dcmread('1-12.dcm')
# ----> 7 cv2.imshow('ds',ds)
#       9 img = ds.pixel_array
#      10 plt.imshow(img)
#
# error: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'imshow'
# > Overload resolution failed:
# >  - mat is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::cuda::GpuMat> for argument 'mat'
# >  - Expected Ptr<cv::UMat> for argument 'mat'
